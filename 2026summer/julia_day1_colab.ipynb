# %% [markdown]
# # 高校数学とJulia言語 Day 1
#
# - 城北中学校・高等学校　中学3年・高校1年
# - 夏期講習会III 2026/8/24~2026/8/28
# - 担当：清水団
#
# ## 本日のテーマ:Google Colabの紹介とJulia言語で計算してみよう!
#
# ### 今年のテーマ「実験する高校数学」
#
# - 整数は**探す**・場合の数は**全部作る**・関数は**描く**・確率は**試す**
#
# ### 5日間の学習予定
#
# - **Day 1**：Google Colabの紹介・Juliaで計算しよう ← 今日
# - **Day 2**：整数問題をプログラムで考えよう
# - **Day 3**：場合の数・組合せを実験しよう
# - **Day 4**：関数・グラフ・最大最小
# - **Day 5**：確率・シミュレーション

# %% [markdown]
# ## Julia言語とは
#
# Juliaは統計処理や科学技術計算、機械学習に強いプログラミング言語です。特に数学的な計算が得意で、数式をそのままコードに書けるのが魅力です。
#
# ### Julia言語の特徴
# - **数学的記法が使える**：`2x` のように数学と同じ書き方ができる
# - **高速計算**：複雑な計算も瞬時に実行
# - **豊富な数学関数**：平方根、三角関数、対数など標準装備
# - **美しいグラフ**：関数のグラフを簡単に描画可能
#
# 公式サイト：https://julialang.org/

# %% [markdown]
# ## Google ColabでJulia言語を使ってみよう!
#
# Google Colab上でJulia言語が使えます。今回の夏期講習会ではこのGoogle Colab上でJulia言語を使います。
#
# ### 📌 設定方法
# **メニュー → ランタイム → ランタイムのタイプを変更 → Julia を選択**
#
# 参考記事：https://zenn.dev/dannchu/articles/296dce4bf7c701

# %% [markdown]
# ## 📝 Google Colab の基本的な使い方
#
# Google Colab（Colaboratory）は、クラウド上で動くJupyterノートブック環境です。PythonやJuliaなどのプログラミング言語を、インストールなしでブラウザ上で実行できます。
#
# ### 🔸 セルの種類
#
# | セルの種類 | 用途 | 入力内容 |
# |-----------|------|----------|
# | **コードセル** | プログラムを書く | Julia, Python などのコード |
# | **テキストセル** | 解説や見出しを書く | Markdown 記法を使った文章や数式 |
#
# ✅ **セルの追加方法**：上部メニュー → `+ コード` または `+ テキスト`
#
# ### 🔸 コードセルの実行
#
# コードセルを選んで **Shift + Enter**（または ▶ ボタン）で実行できます。

# %% [markdown]
# ## Julia言語で基本計算をしてみよう!
#
# まずは四則演算から始めましょう。電卓として使ってみます。

# %%
15 + 7 # 足し算

# %%
15 - 7 # 引き算

# %%
15 * 7 # 掛け算

# %%
15 / 7 # 割り算

# %%
15 // 7 # 割り算（有理数）

# %%
15 % 7 # 割り算の余り

# %%
15 ÷ 7 # 割り算の商　÷は \div + tab

# %% [markdown]
# ## 数学でよく使う関数を試してみよう

# %%
# 平方根（ルート）
sqrt(2)

# %%
# 平方根（ルート）√は \sqrt + tab
√2

# %%
# 円周率π（パイ）
pi

# %%
# 円周率π（パイ）πは \pi + tab
π

# %%
# 自然対数の底（ネイピア数）ℯは \euler + tab
ℯ

# %%
# 黄金比
ϕ = (1 + sqrt(5))/2

# %%
# 数学的な記法が使える!
# 2πは 2*π と同じ意味
2π, 2sqrt(3)

# %%
# 絶対値 abs()
abs(-5)

# %%
# 三角関数
sin(π/6)

# %%
# 度数法で30°
sind(30)

# %%
# べき乗の計算（^を使う）
2^10

# %%
# 分数での厳密計算（//を使う）
1//3 + 3 * (1 - 1//4)

# %% [markdown]
# ## 計算チェック!
#
# 手計算の結果をJuliaで確認してみましょう。
#
# 展開の公式：$(2\sqrt{3}+5)(\sqrt{3}-1) = 6 - 2\sqrt{3} + 5\sqrt{3} - 5 = 1 + 3\sqrt{3}$

# %%
# 左辺を計算
(2sqrt(3) + 5) * (sqrt(3) - 1)

# %%
# 右辺を計算
1 + 3sqrt(3)

# %%
# 両辺が等しいか確認 ≈ は \approx + tab で「ほぼ等しい」の意味
(2sqrt(3) + 5) * (sqrt(3) - 1) ≈ 1 + 3sqrt(3)

# %% [markdown]
# ## 変数を使って計算してみよう
#
# 数学と同じように、文字に数値を代入して計算できます。

# %%
# 変数 x に値を代入
x = 7

# %%
# 変数 y に値を代入
y = 10

# %%
4x - 3y

# %%
(x^2 + y^2)//(x*y)

# %% [markdown]
# ### 数学の公式を確認してみよう!
#
# $x = 2 + \sqrt{3}$, $y = 2 - \sqrt{3}$ のとき
#
# - $x + y = 4$
# - $xy = (2 + \sqrt{3})(2 - \sqrt{3}) = 4 - 3 = 1$
#
# 3乗の和の公式：$x^3 + y^3 = (x + y)^3-3xy(x + y)$

# %%
x , y = 2 + sqrt(3) , 2 - sqrt(3)

# %%
# x + y を計算
x + y

# %%
# x × y を計算
x * y

# %%
# 両辺が等しいか確認
x^3 + y^3 ≈ (x+y)^3 - 3x*y*(x+y)

# %% [markdown]
# ## 範囲（レンジ）と合計
#
# `1:10` は「1から10までの整数」を表します。数列の計算にとても便利です。

# %%
# 1から10までの整数
1:10

# %%
# 中身を全部見るには collect
collect(1:10)

# %%
# 1から100までの和（ガウス少年の計算!）
sum(1:100)

# %%
# 1から10までの積 = 10!
prod(1:10)

# %%
# 奇数だけ：1から始めて2ずつ増やす
collect(1:2:19)

# %% [markdown]
# ## for文：繰り返しの魔法
#
# 同じ処理を何度も繰り返すには `for` 文を使います。
#
# ```julia
# for 変数 in 範囲
#     処理
# end
# ```

# %%
# 1から5まで表示
for i in 1:5
    println(i)
end

# %%
# 7の段の九九
for i in 1:9
    println("7 × $i = $(7i)")
end

# %%
# 1から10までの2乗の値
for i in 1:10
    println("$i の2乗は $(i^2)")
end

# %% [markdown]
# ## if文：条件で分ける
#
# 条件によって処理を変えるには `if` 文を使います。
#
# ```julia
# if 条件
#     処理A
# else
#     処理B
# end
# ```
#
# 条件には `==`（等しい）、`<`、`>`、`%`（余り）などが使えます。

# %%
# 偶数か奇数か判定
n = 10
if n % 2 == 0
    println("$n は偶数")
else
    println("$n は奇数")
end

# %%
# 3で割った余りで分類
n = 100
if n % 3 == 0
    println("$n は3の倍数")
elseif n % 3 == 1
    println("$n は3で割ると1余る")
else
    println("$n は3で割ると2余る")
end

# %% [markdown]
# ## for文 + if文 = 「探す」道具
#
# この2つを組み合わせると、**条件に合う数を全部探す**ことができます。これが「実験する数学」の第一歩です!

# %%
# 1〜1000の中で7の倍数を全部表示してみよう!
for n in 1:1000
    if n % 7 == 0
        println(n)
    end
end

# %%
# 何個あるかは count で一発!
count(n -> n % 7 == 0, 1:1000)

# %%
# 7の倍数の合計も求められる
sum(n for n in 1:1000 if n % 7 == 0)

# %% [markdown]
# ## Day 1 の演習問題
#
# 以下の問題に取り組んでみましょう。
#
# - まずJuliaのコードで計算してみよう
# - 次に、自分の手と頭で解いて、答えをJuliaでチェックしよう
# - ノートブックを保存して、Google Classroomから提出しよう
#
# ### 問題1: 展開と計算
#
# 次の式を計算しよう：
#
# $$(2\sqrt{3}+1)(\sqrt{3}-4)$$
#
# 1. まず、そのままJuliaで計算しよう!
# 2. 次に手で展開して、その値をJuliaで評価しよう!
# 3. 2つの値が等しいかチェックしよう!
#
# ### 問題2: 倍数を探そう
#
# 1〜1000の中で、**3の倍数** は何個あるか。また、その合計はいくつか。
#
# 1. for文とif文で全部表示してみよう
# 2. `count` と `sum` で個数と合計を求めよう
# 3. 等差数列の和の公式で手計算した結果と一致するか確認しよう
#
# ### 問題3: チャレンジ問題
#
# 1〜1000の中で、**3の倍数でも5の倍数でもある数**（=15の倍数）の個数と合計を求めよう。
# `&&`（かつ）を使うと2つの条件を組み合わせられます。
#
# ```julia
# if n % 3 == 0 && n % 5 == 0
# ```

# %% [markdown]
# ## 解答欄
#
# 以下のセルに解答を記入してください。

# %% [markdown]
# ### 問題1の解答

# %%
# 1. そのままJuliaで計算

# %%
# 2. 展開した式を計算

# %%
# 3. 等しいかチェック（≈を使おう）

# %% [markdown]
# ### 問題2の解答

# %%
# 1. for文とif文で表示

# %%
# 2. countとsumで個数と合計

# %%
# 3. 公式との比較

# %% [markdown]
# ### 問題3の解答

# %%
# 3の倍数かつ5の倍数

# %% [markdown]
# ## Day 1 まとめ
#
# 今日学習した内容
#
# - **Google Colab**：ブラウザだけでJuliaが動く実験室
# - **四則演算・数学関数**：`sqrt`, `π`, `sin`, `log` など
# - **変数**：数学と同じように文字に値を代入
# - **範囲**：`1:100` と `sum`, `prod`, `count`
# - **for文・if文**：繰り返しと条件分岐で「数を探す」
#
# 明日は整数問題をプログラムで**実験**します。素数、完全数、そして有名な未解決問題「コラッツ予想」に挑戦しましょう!
